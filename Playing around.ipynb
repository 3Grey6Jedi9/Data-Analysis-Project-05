# %%
import numpy as np
import matplotlib.pyplot as plt
a = np.zeros(1)
a
# Out:
# array([0.])

# %%
b = np.array([[1,1,1],[2,2,2],[3,3,3],[4,4,4]])
b
b.reshape(-1,3)
# Out:
# array([[1, 1, 1],
#        [2, 2, 2],
#        [3, 3, 3],
#        [4, 4, 4]])

# %%
s, x = np.split(np.arange(1, 11), 2)
s, x
# Out:
# (array([1, 2, 3, 4, 5]), array([ 6,  7,  8,  9, 10]))

# %%
rep = np.repeat(2, 6)
rep
# Out:
# array([2, 2, 2, 2, 2, 2])

# %%
sin = np.sin(1.5)
sin
# Out:
# 0.9974949866040544

# %%
s.mean()
# Out:
# 3.0

# %%
x = np.linspace(0, 10*np.pi, 10)
plt.plot(x, np.cos(x))
plt.title('A simple chart')
# Out:
# Text(0.5, 1.0, 'A simple chart')
